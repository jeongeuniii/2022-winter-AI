# %% [markdown]
# ## 10.10 결정트리 구현해보기

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X, y = iris.data, iris.target

# %%
from sklearn.tree import DecisionTreeClassifier
dec_tree = DecisionTreeClassifier(max_depth=3)
dec_tree.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
from sklearn.tree import export_graphviz
export_graphviz(
  dec_tree,
  out_file=("./dec_tree_for_iris.dot"),
  feature_names=iris.feature_names,
  class_names = ['setosa', 'versicolor', 'virginica'] # 2쇄에 추가
)

# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 4EFA-E7CA
#
#  C:\Users\AI10 디렉터리
#
# 2023-01-10  오후 02:02    <DIR>          .
# 2023-01-10  오후 02:02    <DIR>          ..
# 2023-01-10  오후 01:57    <DIR>          .conda
# 2022-12-26  오전 11:16    <DIR>          .idlerc
# 2023-01-10  오후 02:01    <DIR>          .ipynb_checkpoints
# 2023-01-03  오전 10:47    <DIR>          .ipython
# 2023-01-03  오전 10:42    <DIR>          .jupyter
# 2023-01-03  오전 10:51    <DIR>          .matplotlib
# 2022-07-26  오후 03:33    <DIR>          3D Objects
# 2023-01-10  오후 01:57    <DIR>          anaconda3
# 2022-07-26  오후 03:33    <DIR>          Contacts
# 2023-01-06  오후 01:07            25,930 Day10.ipynb
# 2023-01-09  오전 11:53           975,916 Day11-1.ipynb
# 2023-01-09  오후 03:36            44,059 Day11-2.ipynb
# 2023-01-10  오후 02:02             1,460 Day12-1.ipynb
# 2023-01-03  오전 11:45            57,180 Day8.ipynb
# 2023-01-04  오후 04:12            93,833 Day9.ipynb
# 2023-01-10  오후 02:02             1,053 dec_tree_for_iris.dot
# 2023-01-10  오후 01:59            63,117 dec_tree_for_iris.jpg
# 2022-12-28  오후 04:27    <DIR>          Desktop
# 2022-08-23  오후 03:14    <DIR>          Documents
# 2023-01-09  오후 03:56    <DIR>          Downloads
# 2022-07-26  오후 03:33    <DIR>          Favorites
# 2022-07-26  오후 03:33    <DIR>          Links
# 2022-07-26  오후 03:33    <DIR>          Music
# 2022-08-18  오후 01:16    <DIR>          My project
# 2022-08-18  오후 04:22    <DIR>          My project (1)
# 2022-08-18  오후 04:23    <DIR>          My project (2)
# 2022-07-27  오전 10:20    <DIR>          OneDrive
# 2022-07-26  오후 03:34    <DIR>          Pictures
# 2022-09-13  오후 12:17    <DIR>          PycharmProjects
# 2022-07-26  오후 03:33    <DIR>          Saved Games
# 2022-07-26  오후 03:34    <DIR>          Searches
# 2022-08-18  오전 09:19    <DIR>          Videos
#                8개 파일           1,262,548 바이트
#               26개 디렉터리  407,042,502,656 바이트 남음

# %%
# !dot -Tjpg dec_tree_for_iris.dot -o dec_tree_for_iris.jpg

import matplotlib.pyplot as plt
dec_tree_img = plt.imread('./dec_tree_for_iris.jpg')
plt.figure(num=None, figsize=(12, 8), dpi=80, 
           facecolor='w', edgecolor='k')
plt.imshow(dec_tree_img)
